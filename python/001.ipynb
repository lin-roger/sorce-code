# %%
import numpy as np

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- --------------
# altgraph               0.17
# appdirs                1.4.4
# apsw                   3.34.0.post1
# apt-xapian-index       0.49
# argon2-cffi            21.1.0
# arrow                  0.17.0
# astor                  0.8.1
# atomicwrites           1.4.0
# attrs                  20.3.0
# Babel                  2.8.0
# backcall               0.2.0
# beautifulsoup4         4.9.3
# bleach                 4.1.0
# blinker                1.4
# certifi                2020.6.20
# cffi                   1.14.6
# chardet                4.0.0
# click                  7.1.2
# colorama               0.4.4
# colour                 0.1.5
# command-not-found      0.3
# coverage               5.1
# cryptography           3.3.2
# css-parser             1.0.6
# cssselect              1.1.0
# cssutils               1.0.2
# cupshelpers            1.0
# dbus-python            1.2.16
# debugpy                1.5.1
# ...

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6461/3793406994.py in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
